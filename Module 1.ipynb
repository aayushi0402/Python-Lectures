# %% [markdown]
# # Python Overview

# %% [markdown]
# " Python is powerful... and fast;
# plays well with others;
# runs everywhere;
# is friendly & easy to learn;
# is Open."
# -Python Website
#
#
#
# Python was conceived in the late 1980s by Guido van Rossum at Centrum Wiskunde & Informatica (CWI) in the Netherlands as a successor to the ABC language (itself inspired by SETL), capable of exception handling and interfacing with the Amoeba operating system.
#
# It is a high-level, interpreted, interactive and object-oriented scripting language. Python is one of the most readable languages. It is simple since it uses English keywords frequently that helps its users write scalable and good code. It has fewer syntactical constructions than other languages.

# %% [markdown]
# # Industry Trends
#
# When talking about trends, what gives a clear picture and a better understanding when compared to a visual representation?
# After all, pictures speak louder than words.

# %% [markdown]
# ![21017.jpeg](attachment:21017.jpeg)

# %% [markdown]
# ![Payscale-in-Python-01.jpg](attachment:Payscale-in-Python-01.jpg)

# %% [markdown]
# ![top-10-python-development-trends.jpg](attachment:top-10-python-development-trends.jpg)

# %% [markdown]
# # Usage of Python in Industry
#
# ### The top most positions in the industry are acquired by the following.
#
#    * Data Science
#    * Machine Learning and Artificial Intelligence
#    * Data Analytics
#    * Robotics
#    * Internet of Things
#    * Web Development
#    * Fintech
#
#    Python has also been used for creating Desktop GUIs, Web Scraping Applications, Business Applications, Audio/Video Applications, CAD applications and embedded applications.
#
# ### Top Companies using Python
#
# #### Large tech companies
#
#  * Uber uses a significant amount of Python, which they documented in a series of engineering posts. Part one talks about the lower backend levels, which are written in Python, with Node.js, Go and Java mixed in.
#
#  * Netflix uses Python widely in its organization to run chaos engineering tests. Netflix also wrote a 2019 update for PyCon US to give more detail on what teams and projects work in Python.
#
#  * Google uses Python extensively and officially supports it internally as one of their three core languages, the other two being Java and Golang.
#
#  * PayPal uses Python across their entire infrastructure and often writes great technical blog posts on packaging, optimization using C and configuring DNS.
#
#
#
#
#
#
#
#    PYTHON IS EVERYWHERE!
#
#
#
#
#    PS,
#
#     Python you are the best.

# %% [markdown]
# # Language Features
#
# If you still aren't convinced as to why you should be learning Python already, here are few more reasons to do so.

# %% [markdown]
# #### 1. Easy to code:
# Python being a high-level programming language is very easy to learn as compared to other languages like C, C#, Javascript, Java, etc. And because of its simplicity, anybody can learn python basics in a few hours or days. It is a developer-friendly language.
#
# #### 2. Free and Open Source:
# Python language is freely available at the official website and you can download it on your computer right away! Not only that, Python website also has an official documentation for everything it provides!
# Also, since it is open-source, this means that source code is also available to the public.
#
# #### 3. Object-Oriented Language:
# One of the key features of python is Object-Oriented programming. It supports classes, objects and OOP features like encapsulation, etc.
#
# #### 4. GUI Programming Support:
# Graphical User interfaces can be made using a module such as PyQt5, PyQt4, wxPython, or Tk in python.
# PyQt5 is the most popular option for creating graphical apps with Python.
#
# #### 5. High-Level Language:
# Python is a high-level language. When we write programs in python, we do not need to remember the system architecture, nor do we need to manage the memory.
#
# #### 6. Extensible feature:
# Python is a Extensible language. We can write us some Python code into C or C++ language and also we can compile that code in C/C++ language.
#
# #### 7. Portable language:
# Python language is also a portable language. For example, if we have python code for windows and if we want to run this code on other platforms such as Linux, Unix, and Mac then we do not need to change it, we can run this code on any platform.
#
# #### 8. Integrated language:
# Python is also an Integrated language because we can easily integrated python with other languages like c, c++, etc.
#
# #### 9. Interpreted Language:
# Python is an Interpreted Language because Python code is executed line by line at a time. like other languages C, C++, Java, etc. Since there is no need to compile Python code, it makes it easier to debug. The source code of python is converted into an immediate form called bytecode.
#
# #### 10. Large Standard Library
# Python has a large standard library which provides a rich set of module and functions so you do not have to write your own code for every single thing. There are many libraries present in python for such as regular expressions, unit-testing, web browsers, etc.
#
# #### 11. Dynamically Typed Language:
# Python is a dynamically-typed language. That means the type (for example- int, double, long, etc.) for a variable is decided at run time not in advance because of this feature we don’t need to specify the type of variable.
